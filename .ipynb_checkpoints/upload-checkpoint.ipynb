# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\admin\anaconda3\ana\lib\site-packages (2.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (9.0.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\ana\lib\site-packages (from google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\admin\appdata\roaming\python\python313\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\admin\anaconda3\ana\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (44.0.1)
# Requirement already satisfied: certifi in c:\users\admin\appdata\roaming\python\python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\ana\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\anaconda3\ana\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\ana\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\admin\anaconda3\ana\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\ana\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\ana\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\admin\anaconda3\ana\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.8)

# %%
import os
os.getcwd()
# Out:
# 'C:\\IITM AGENTIC AI WORKFLOW\\Mr.sameer\\sameer _project\\session_1'

# %%
from dotenv import load_dotenv
import os

loaded = load_dotenv()

print("Loaded:", loaded)
print("API Key:", os.getenv("GOOGLE_API_KEY"))
# Out:
# Loaded: False
# API Key: None

# %%
# %reset -f

# %%
# !pip uninstall google-generativeai

# %%
import os
import time
import mimetypes
from pathlib import Path

from dotenv import load_dotenv
from google import genai
import os
load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY") 
client = genai.Client(api_key=API_KEY, vertexai=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       9 load_dotenv()
#      10 API_KEY = os.getenv("GOOGLE_API_KEY")
# ---> 11 client = genai.Client(api_key=API_KEY, vertexai=False)
#
# File ~\anaconda3\ana\Lib\site-packages\google\genai\client.py:458, in Client.__init__(self, enterprise, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     455   else:
#     456     http_options = HttpOptions(base_url=base_url)
# --> 458 self._api_client = self._get_api_client(
#     459     vertexai=resolved_vertexai,
#     460     api_key=api_key,
#     461     credentials=credentials,
#     462     project=project,
#     463     location=location,
#     464     debug_config=self._debug_config,
#     465     http_options=http_options,
#     466 )
#     468 self._aio = AsyncClient(self._api_client)
#     469 self._models = Models(self._api_client)
#
# File ~\anaconda3\ana\Lib\site-packages\google\genai\client.py:506, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     489 if debug_config and debug_config.client_mode in [
#     490     'record',
#     491     'replay',
#     492     'auto',
#     493 ]:
#     494   return ReplayApiClient(
#     495       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     496       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)
#     503       http_options=http_options,
#     504   )
# --> 506 return BaseApiClient(
#     507     vertexai=vertexai,
#     508     api_key=api_key,
#     509     credentials=credentials,
#     510     project=project,
#     511     location=location,
#     512     http_options=http_options,
#     513 )
#
# File ~\anaconda3\ana\Lib\site-packages\google\genai\_api_client.py:783, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     781 else:  # Implicit initialization or missing arguments.
#     782   if not self.api_key:
# --> 783     raise ValueError(
#     784         'No API key was provided. Please pass a valid API key. Learn how to'
#     785         ' create an API key at'
#     786         ' https://ai.google.dev/gemini-api/docs/api-key.'
#     787     )
#     788   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     789   self._http_options.api_version = 'v1beta'
#
# ValueError: No API key was provided. Please pass a valid API key. Learn how to create an API key at https://ai.google.dev/gemini-api/docs/api-key.

# %%
def guess_mime(path: Path) -> str:
    mime, _ = mimetypes.guess_type(str(path))
    return mime or "application/octet-stream"
 
 
def wait_operation(op, poll_s: float = 2.0):
    while not getattr(op, "done", False):
        time.sleep(poll_s)
        op = client.operations.get(op)
    err = getattr(op, "error", None)
    if err:
        raise RuntimeError(f"Operation failed: {err}")
    return op
 
 
def get_or_create_store(display_name: str):
    for s in client.file_search_stores.list():
        if getattr(s, "display_name", None) == display_name:
            return s
    return client.file_search_stores.create(config={"display_name": display_name})

# %%
DATA_DIR = Path("data")
if not DATA_DIR.exists():
    raise FileNotFoundError(f"Folder not found: {DATA_DIR.resolve()}")
 
STORE_DISPLAY_NAME = "deployment-store"  # change if you want
 
 
store = get_or_create_store(STORE_DISPLAY_NAME)
store_name = store.name  # looks like "fileSearchStores/...."
store_name
 
files = [p for p in DATA_DIR.rglob("*") if p.is_file()]
len(files), [str(p.relative_to(DATA_DIR)) for p in files[:10]]
 
uploaded_relpaths = []
 
for p in files:
    rel = p.relative_to(DATA_DIR)
    mime = guess_mime(p)
 
    print(f"Uploading: {rel}  (mime={mime})")
 
    op = client.file_search_stores.upload_to_file_search_store(
        file_search_store_name=store_name,
        file=str(p),
        config={
            "display_name": str(rel),   # shows up in citations later
            "mime_type": mime,
            "custom_metadata": [
                {"key": "rel_path", "string_value": str(rel)},
                {"key": "ext", "string_value": p.suffix.lower().lstrip(".")},
            ],
        },
    )
    wait_operation(op)
    uploaded_relpaths.append(str(rel))
 
print(f"Uploaded {len(uploaded_relpaths)} files into {store_name}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19600/4208873943.py in <module>
#       6
#       7
# ----> 8 store = get_or_create_store(STORE_DISPLAY_NAME)
#       9 store_name = store.name  # looks like "fileSearchStores/...."
#      10 store_name
#
# ~\AppData\Local\Temp/ipykernel_19600/4228583111.py in get_or_create_store(display_name)
#      15
#      16 def get_or_create_store(display_name: str):
# ---> 17     for s in client.file_search_stores.list():
#      18         if getattr(s, "display_name", None) == display_name:
#      19             return s
#
# AttributeError: 'Client' object has no attribute 'file_search_stores'

# %%
dir(client)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aio',
#  '_api_client',
#  '_batches',
#  '_caches',
#  '_debug_config',
#  '_files',
#  '_get_api_client',
#  '_models',
#  '_operations',
#  '_tokens',
#  '_tunings',
#  'aio',
#  'auth_tokens',
#  'batches',
#  'caches',
#  'chats',
#  'close',
#  'files',
#  'models',
#  'operations',
#  'tunings',
#  'vertexai']

# %%
def count_documents_in_store(store_name: str) -> int:
    # lists processed "documents" inside the File Search store
    return sum(1 for _ in client.file_search_stores.documents.list(parent=store_name))
 
 
target = len(uploaded_relpaths)
timeout_s = 900
poll_s = 3
 
t0 = time.time()
while True:
    doc_count = count_documents_in_store(store_name)
    print(f"Documents indexed: {doc_count}/{target}")
 
    if doc_count >= target:
        print("Store is ready for retrieval.")
        break
 
    if time.time() - t0 > timeout_s:
        raise TimeoutError(f"Timed out waiting for indexing. Indexed {doc_count}/{target}")
 
    time.sleep(poll_s)
